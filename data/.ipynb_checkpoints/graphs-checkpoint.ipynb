# %%
import pandas as pd
import numpy as np
import datetime
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use(['seaborn-whitegrid'])
plt.rcParams['font.family'] = 'AppleGothic'

# %%
boston = pd.read_csv('boston_marathon_yearly.csv', index_col=0)
chicago = pd.read_csv('chicago_marathon_yearly.csv', index_col=0)
olympic = pd.read_csv('olympic_marathon_records.csv', index_col=0)

# %%
olympic['중도포기 및 완주자'] = olympic['중도포기자'] + olympic['완주자']
olympic['중도포기 비율'] = olympic['중도포기자'] / olympic['중도포기 및 완주자']

# %%
fig, axes = plt.subplots(1, 3, sharex=True, sharey=False, figsize=(15,5))
fig.suptitle('올림픽 마라톤 기록 추이')

sns.lineplot(ax=axes[0], x="year", y="금메달_기록", data=olympic)
sns.lineplot(ax=axes[1],x="year", y="상위10위_평균_기록", data=olympic)
sns.lineplot(ax=axes[2],x="year", y="중도포기 비율", data=olympic)
# Out:
# <AxesSubplot:xlabel='year', ylabel='중도포기 비율'>

# %%
olympic_after_40 = olympic[olympic['year']>1940]

fig, axes = plt.subplots(1, 3, sharex=True, sharey=False, figsize=(20,6))
fig.suptitle('1940년대 이후 기온에 따른 올림픽 마라톤 기록 분포')

sns.scatterplot(ax=axes[0], x="기온", y="금메달_기록", hue="year", style="성별", palette="Blues", s=100, legend=False, data=olympic_after_40)
sns.scatterplot(ax=axes[1], x="기온", y="상위10위_평균_기록", hue="year", style="성별", palette="Blues", s=100, legend=False, data=olympic_after_40)
sns.scatterplot(ax=axes[2], x="기온", y="중도포기 비율", hue="year", style="성별",  palette="Blues", s=100, data=olympic_after_40)

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

axes[0].title.set_text('금메달 기록')
axes[1].title.set_text('상위10위 평균 기록')
axes[2].title.set_text('중도포기 비율')

plt.show()

# %%
fig, axes = plt.subplots(1, 3, sharex=True, sharey=False, figsize=(15,5))
fig.suptitle('보스톤 마라톤 기록 추이')

sns.lineplot(ax=axes[0], x="year", y="금메달_기록", data=boston)
sns.lineplot(ax=axes[1],x="year", y="상위10위_평균_기록", data=boston)
sns.lineplot(ax=axes[2],x="year", y="상위500위_평균_기록", data=boston)
# Out:
# <AxesSubplot:xlabel='year', ylabel='상위500위_평균_기록'>

# %%
fig, axes = plt.subplots(1, 3, sharex=True, sharey=False, figsize=(15,5))
fig.suptitle('시카고 마라톤 기록 추이')

sns.lineplot(ax=axes[0], x="year", y="금메달_기록", data=chicago)
sns.lineplot(ax=axes[1],x="year", y="상위10위_평균_기록", data=chicago)
sns.lineplot(ax=axes[2],x="year", y="상위500위_평균_기록", data=chicago)
# Out:
# <AxesSubplot:xlabel='year', ylabel='상위500위_평균_기록'>

# %%
fig, axes = plt.subplots(1, 3, sharex=True, sharey=False, figsize=(20,6))
fig.suptitle('2010년대 이후 기온에 따른 보스톤 마라톤 기록 분포')

sns.scatterplot(ax=axes[0], x="기온", y="금메달_기록", hue="year", style="성별", palette="Blues", s=100, legend=False, data=boston)
sns.scatterplot(ax=axes[1], x="기온", y="상위10위_평균_기록", hue="year", style="성별", palette="Blues", s=100, legend=False, data=boston)
sns.scatterplot(ax=axes[2], x="기온", y="상위500위_평균_기록", hue="year", style="성별",  palette="Blues", s=100, data=boston)

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

axes[0].title.set_text('금메달 기록')
axes[1].title.set_text('상위10위 평균 기록')
axes[2].title.set_text('상위500위_평균_기록')

plt.show()

# %%
fig, axes = plt.subplots(1, 3, sharex=True, sharey=False, figsize=(20,6))
fig.suptitle('2010년대 이후 기온에 따른 시카고 마라톤 기록 분포')

sns.scatterplot(ax=axes[0], x="기온", y="금메달_기록", hue="year", style="성별", palette="Blues", s=100, legend=False, data=chicago)
sns.scatterplot(ax=axes[1], x="기온", y="상위10위_평균_기록", hue="year", style="성별", palette="Blues", s=100, legend=False, data=chicago)
sns.scatterplot(ax=axes[2], x="기온", y="상위500위_평균_기록", hue="year", style="성별",  palette="Blues", s=100, data=chicago)

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

axes[0].title.set_text('금메달 기록')
axes[1].title.set_text('상위10위 평균 기록')
axes[2].title.set_text('상위500위_평균_기록')

plt.show()

# %%
fig, axes = plt.subplots(1, 3, sharex=True, sharey=False, figsize=(20,6))
fig.suptitle('2010년대 이후 습도에 따른 보스톤 마라톤 기록 분포')

sns.scatterplot(ax=axes[0], x="습도", y="금메달_기록", hue="year", style="성별", palette="Blues", s=100, legend=False, data=boston)
sns.scatterplot(ax=axes[1], x="습도", y="상위10위_평균_기록", hue="year", style="성별", palette="Blues", s=100, legend=False, data=boston)
sns.scatterplot(ax=axes[2], x="습도", y="상위500위_평균_기록", hue="year", style="성별",  palette="Blues", s=100, data=boston)

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

axes[0].title.set_text('금메달 기록')
axes[1].title.set_text('상위10위 평균 기록')
axes[2].title.set_text('상위500위_평균_기록')

plt.show()

# %%
fig, axes = plt.subplots(1, 3, sharex=True, sharey=False, figsize=(20,6))
fig.suptitle('2010년대 이후 습도에 따른 시카고 마라톤 기록 분포')

sns.scatterplot(ax=axes[0], x="습도", y="금메달_기록", hue="year", style="성별", palette="Blues", s=100, legend=False, data=chicago)
sns.scatterplot(ax=axes[1], x="습도", y="상위10위_평균_기록", hue="year", style="성별", palette="Blues", s=100, legend=False, data=chicago)
sns.scatterplot(ax=axes[2], x="습도", y="상위500위_평균_기록", hue="year", style="성별",  palette="Blues", s=100, data=chicago)

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

axes[0].title.set_text('금메달 기록')
axes[1].title.set_text('상위10위 평균 기록')
axes[2].title.set_text('상위500위_평균_기록')

plt.show()

# %%
fig, axes = plt.subplots(1, 3, sharex=True, sharey=False, figsize=(20,6))
fig.suptitle('2010년대 이후 바람에 따른 보스톤 마라톤 기록 분포')

sns.scatterplot(ax=axes[0], x="바람", y="금메달_기록", hue="year", style="성별", palette="Blues", s=100, legend=False, data=boston)
sns.scatterplot(ax=axes[1], x="바람", y="상위10위_평균_기록", hue="year", style="성별", palette="Blues", s=100, legend=False, data=boston)
sns.scatterplot(ax=axes[2], x="바람", y="상위500위_평균_기록", hue="year", style="성별",  palette="Blues", s=100, data=boston)

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

axes[0].title.set_text('금메달 기록')
axes[1].title.set_text('상위10위 평균 기록')
axes[2].title.set_text('상위500위_평균_기록')

plt.show()

# %%
fig, axes = plt.subplots(1, 3, sharex=True, sharey=False, figsize=(20,6))
fig.suptitle('2010년대 이후 바람에 따른 시카고 마라톤 기록 분포')

sns.scatterplot(ax=axes[0], x="바람", y="금메달_기록", hue="year", style="성별", palette="Blues", s=100, legend=False, data=chicago)
sns.scatterplot(ax=axes[1], x="바람", y="상위10위_평균_기록", hue="year", style="성별", palette="Blues", s=100, legend=False, data=chicago)
sns.scatterplot(ax=axes[2], x="바람", y="상위500위_평균_기록", hue="year", style="성별",  palette="Blues", s=100, data=chicago)

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

axes[0].title.set_text('금메달 기록')
axes[1].title.set_text('상위10위 평균 기록')
axes[2].title.set_text('상위500위_평균_기록')

plt.show()

# %%
boston_indv = pd.read_csv('boston_marathon_individual.csv', index_col=0)
chicago_indv = pd.read_csv('chicago_marathon_individual.csv', index_col=0)
olympic_indv = pd.read_csv('olympic_marathon_individual.csv', index_col=0)

# %%
codes = pd.read_csv('countries_code.csv')

# %%
olympic_indv = olympic_indv.drop_duplicates()

# %%
codes = codes.rename(columns={'IOC':'country_code'})

# %%
olympic_indv=pd.merge(olympic_indv, codes[['country_code', 'ISO']], on='country_code')

# %%
gdp = pd.read_csv('gdp_by_year.csv')

# %%
del gdp['Country Name']
del gdp['Indicator Name']
del gdp['Indicator Code']
del gdp['Unnamed: 65']

# %%
gdp = gdp.set_index('Country Code')

# %%
gdp_by_country = gdp.stack(level=0).reset_index()

# %%
gdp_by_country = gdp_by_country.rename(columns={'level_1':'year', 0:'gdp', 'Country Code':'country_code'})

# %%
gdp_by_country = gdp_by_country.astype({'year':'int64'})

# %%
gdp_by_country = gdp_by_country.rename(columns={'country_code':'ISO'})

# %%
olympic_indv = pd.merge(gdp_by_country, olympic_indv, on=['ISO', 'year'], how='right')

# %%
olympic_indv['출신국_평균_위도'] = [abs(lat) for lat in olympic_indv['출신국_평균_위도']]

# %%
olympic_fin = olympic_indv[olympic_indv['time'] != 'None'].reset_index()
olympic_fin['time'] = pd.to_datetime(olympic_fin['time'])
olympic_fin['time'] = [x.time() for x in olympic_fin['time'] ]

# %%
olympic_fin = olympic_fin[olympic_fin['year']>=1980]

# %%
oly_years = olympic_fin['year'].unique()

# %%
oly_years
# Out:
# array([2016, 2012, 2008, 2004, 2000, 1996, 1992, 1988, 1984])

# %%
for i in range(len(olympic_fin)):
    minute = olympic_fin.loc[i, 'time'].hour * 60 + olympic_fin.loc[i, 'time'].minute
    olympic_fin.loc[i, 'minutes'] = minute

# %%
fig, axes = plt.subplots(3, 3, sharex=True, sharey=False, figsize=(15,6))
fig.suptitle('올림픽 마라톤 기록 분포')


sns.histplot(ax=axes[0,0], data=olympic_fin[olympic_fin.year==2016], x="minutes", hue="gender", element="poly")
sns.histplot(ax=axes[0,1], data=olympic_fin[olympic_fin.year==2012], x="minutes", hue="gender", element="poly")
sns.histplot(ax=axes[0,2], data=olympic_fin[olympic_fin.year==2008], x="minutes", hue="gender", element="poly")
sns.histplot(ax=axes[1,0], data=olympic_fin[olympic_fin.year==2004], x="minutes", hue="gender", element="poly")
sns.histplot(ax=axes[1,1], data=olympic_fin[olympic_fin.year==2000], x="minutes", hue="gender", element="poly")
sns.histplot(ax=axes[1,2], data=olympic_fin[olympic_fin.year==1996], x="minutes", hue="gender", element="poly")
sns.histplot(ax=axes[2,0], data=olympic_fin[olympic_fin.year==1992], x="minutes", hue="gender", element="poly")
sns.histplot(ax=axes[2,1], data=olympic_fin[olympic_fin.year==1988], x="minutes", hue="gender", element="poly")
sns.histplot(ax=axes[2,2], data=olympic_fin[olympic_fin.year==1984], x="minutes", hue="gender", element="poly")


axes[0,0].title.set_text('2016')
axes[0,1].title.set_text('2012')
axes[0,2].title.set_text('2008')
axes[1,0].title.set_text('2004')
axes[1,1].title.set_text('2000')
axes[1,2].title.set_text('1996')
axes[2,0].title.set_text('1992')
axes[2,1].title.set_text('1988')
axes[2,2].title.set_text('1984')

plt.show()

# %%
boston_indv['Latitude (average)'] = [abs(lat) for lat in boston_indv['Latitude (average)']]

# %%
boston_indv['OfficialTime'] = pd.to_datetime(boston_indv['OfficialTime'])
boston_indv['OfficialTime'] = [x.time() for x in boston_indv['OfficialTime'] ]

# %%
for i in range(len(boston_indv)):
    minute = boston_indv.loc[i, 'OfficialTime'].hour * 60 + boston_indv.loc[i, 'OfficialTime'].minute
    boston_indv.loc[i, 'minutes'] = minute

# %%
fig, axes = plt.subplots(3, 3, sharex=True, sharey=False, figsize=(15,6))
fig.suptitle('보스톤 마라톤 기록 분포')

sns.histplot(ax=axes[0,0], data=boston_indv[boston_indv.year==2019], x="minutes", hue="gender", element="poly")
sns.histplot(ax=axes[0,1], data=boston_indv[boston_indv.year==2018], x="minutes", hue="gender", element="poly")
sns.histplot(ax=axes[0,2], data=boston_indv[boston_indv.year==2017], x="minutes", hue="gender", element="poly")
sns.histplot(ax=axes[1,0], data=boston_indv[boston_indv.year==2016], x="minutes", hue="gender", element="poly")
sns.histplot(ax=axes[1,1], data=boston_indv[boston_indv.year==2015], x="minutes", hue="gender", element="poly")
sns.histplot(ax=axes[1,2], data=boston_indv[boston_indv.year==2014], x="minutes", hue="gender", element="poly")
sns.histplot(ax=axes[2,0], data=boston_indv[boston_indv.year==2013], x="minutes", hue="gender", element="poly")
sns.histplot(ax=axes[2,1], data=boston_indv[boston_indv.year==2012], x="minutes", hue="gender", element="poly")
sns.histplot(ax=axes[2,2], data=boston_indv[boston_indv.year==2011], x="minutes", hue="gender", element="poly")

axes[0,0].title.set_text('2019')
axes[0,1].title.set_text('2018')
axes[0,2].title.set_text('2017')
axes[1,0].title.set_text('2016')
axes[1,1].title.set_text('2015')
axes[1,2].title.set_text('2014')
axes[2,0].title.set_text('2013')
axes[2,1].title.set_text('2012')
axes[2,2].title.set_text('2011')

plt.show()

# %%
chicago_indv['Latitude (average)'] = [abs(lat) for lat in chicago_indv['Latitude (average)']]

# %%
chicago_indv['finish'] = pd.to_datetime(chicago_indv['finish'])
chicago_indv['finish'] = [x.time() for x in chicago_indv['finish'] ]

# %%
for i in range(len(chicago_indv)):
    minute = chicago_indv.loc[i, 'finish'].hour * 60 + chicago_indv.loc[i, 'finish'].minute
    chicago_indv.loc[i, 'finish'] = minute

# %%
fig, axes = plt.subplots(3, 3, sharex=True, sharey=False, figsize=(15,6))
fig.suptitle('시카고 마라톤 기록 분포')

sns.histplot(ax=axes[0,0], data=chicago_indv[chicago_indv.year==2019], x="finish", hue="gender", element="poly")
sns.histplot(ax=axes[0,1], data=chicago_indv[chicago_indv.year==2018], x="finish", hue="gender", element="poly")
sns.histplot(ax=axes[0,2], data=chicago_indv[chicago_indv.year==2017], x="finish", hue="gender", element="poly")
sns.histplot(ax=axes[1,0], data=chicago_indv[chicago_indv.year==2016], x="finish", hue="gender", element="poly")
sns.histplot(ax=axes[1,1], data=chicago_indv[chicago_indv.year==2015], x="finish", hue="gender", element="poly")
sns.histplot(ax=axes[1,2], data=chicago_indv[chicago_indv.year==2014], x="finish", hue="gender", element="poly")
sns.histplot(ax=axes[2,0], data=chicago_indv[chicago_indv.year==2013], x="finish", hue="gender", element="poly")
sns.histplot(ax=axes[2,1], data=chicago_indv[chicago_indv.year==2012], x="finish", hue="gender", element="poly")
sns.histplot(ax=axes[2,2], data=chicago_indv[chicago_indv.year==2011], x="finish", hue="gender", element="poly")

axes[0,0].title.set_text('2019')
axes[0,1].title.set_text('2018')
axes[0,2].title.set_text('2017')
axes[1,0].title.set_text('2016')
axes[1,1].title.set_text('2015')
axes[1,2].title.set_text('2014')
axes[2,0].title.set_text('2013')
axes[2,1].title.set_text('2012')
axes[2,2].title.set_text('2011')

plt.show()
